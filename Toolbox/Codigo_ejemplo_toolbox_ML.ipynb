# %%
import pandas as pd
import toolbox_ML as tools_ML

# %%
df_titanic = pd.read_csv("./data/titanic.csv")

df_titanic_sin_NaN = df_titanic.dropna()

df_practica_rl = pd.read_csv("./data/practica_regresion_lineal.csv", sep="|")

# %% [markdown]
# # Función describe_df

# %%
tools_ML.describe_df(df_titanic)
# Out:
#                survived pclass     sex      age  sibsp  parch     fare  \
# Tipos             int64  int64  object  float64  int64  int64  float64
# % Faltante          0.0    0.0     0.0    19.87    0.0    0.0      0.0
# Valores Únicos        2      3       2       88      7      7      248
# % Cardinalidad     0.22   0.34    0.22     9.88   0.79   0.79    27.83
#
#                embarked   class     who adult_male    deck embark_town  \
# Tipos            object  object  object       bool  object      object
# % Faltante         0.22     0.0     0.0        0.0   77.22        0.22
# Valores Únicos        3       3       3          2       7           3
# % Cardinalidad     0.34    0.34    0.34       0.22    0.79        0.34
#
#                  alive alone
# Tipos           object  bool
# % Faltante         0.0   0.0
# Valores Únicos       2     2
# % Cardinalidad    0.22  0.22

# %% [markdown]
# # Función tipifica_variables

# %%
tools_ML.tipifica_variables(df=df_titanic_sin_NaN, umbral_categoria=10, umbral_continua=20)
# Out:
#    nombre_variable tipo_variable  cardinalidad  cardinalidad_porcentaje  \
# 0         survived         int64             2                     1.10
# 1           pclass         int64             3                     1.65
# 2              sex        object             2                     1.10
# 3              age       float64            63                    34.62
# 4            sibsp         int64             4                     2.20
# 5            parch         int64             4                     2.20
# 6             fare       float64            93                    51.10
# 7         embarked        object             3                     1.65
# 8            class        object             3                     1.65
# 9              who        object             3                     1.65
# 10      adult_male          bool             2                     1.10
# 11            deck        object             7                     3.85
# 12     embark_town        object             3                     1.65
# 13           alive        object             2                     1.10
# 14           alone          bool             2                     1.10
#
#         tipo_sugerido
# 0             Binaria
# 1          Categórica
# 2             Binaria
# 3   Numérica continua
# 4          Categórica
# 5          Categórica
# 6   Numérica continua
# 7          Categórica
# 8          Categórica
# 9          Categórica
# 10            Binaria
# 11         Categórica
# 12         Categórica
# 13            Binaria
# 14            Binaria

# %% [markdown]
# # Función get_features_num_regression

# %%
features_numericas = tools_ML.get_features_num_regression(df=df_titanic_sin_NaN, target_col="fare", umbral_corr=0.2, pvalue=0.0001)
print(features_numericas)
# Out:
# ['pclass', 'sibsp', 'parch', 'alone']

# %% [markdown]
# # Función plot_features_num_regression

# %%
features_numericas = tools_ML.plot_features_num_regression(df=df_practica_rl, target_col="MEDV", lista_columnas="", umbral_corr=0.6, umbral_pvalue=0.05, limite_pairplot=2)
print(features_numericas)
# Out:
# ['RM', 'LSTAT']

# %% [markdown]
# # Función get_features_cat_regression

# %%
features_categoricas = tools_ML.get_features_cat_regression(df=df_titanic_sin_NaN, target_col="fare", umbral_pvalue=0.0005)
print(features_categoricas)
# Out:
# ['class', 'deck']

# %% [markdown]
# # Función plot_features_cat_regression

# %%
features_categoricas = tools_ML.plot_features_cat_regression(dataframe=df_titanic_sin_NaN, target_col="fare", columns= [], pvalue=0.05, with_individual_plot=True)
print(features_categoricas)
# Out:
# ['embarked', 'class', 'who', 'deck', 'embark_town']
